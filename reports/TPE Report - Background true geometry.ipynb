# %% [markdown]
# # Tandem Piercer Experiment - Measurement report
#
# ## Initialization
#
# Load required Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility (and optionally output current working directory name):

# %%
# %pylab inline
#print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_20*");
# Out:
# ../experiments\default_2022_2_20_0_9\statistics.csv
# ../experiments\default_2022_2_20_10_59\statistics.csv
# ../experiments\default_2022_2_20_18_45\statistics.csv

# %% [markdown]
# Output header, general settings, instrument details and trigger info for the selected measurement:

# %%
directory1 = "../experiments\default_2022_2_20_18_45"
get_report_header(directory1)
# Out:
# <h2>Background whole spectrum</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>SCA `(pos[:-1] & ~pos[1:]).nonzero()`</td></tr>                <tr><th>Sample size</th><td>8e-06s</td></tr>                <tr><th>Resolution</th><td>8e-09s</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>true</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.7          | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 842     | 576     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay (samples)</th><td>0</td></tr>            <tr><th>Direction</th><td>RISING</td></tr>            <tr><th>Threshold (ADC)</th><td>16384</td></tr>            </table>

# %%
st = Stats()
st.read_stats_dataframe(directory1);
st.print_basic_data();
# Out:
# Start time:	2022-02-20 16:45:22
# End time:	2022-02-20 22:45:22
# Time elapsed:	6:00:00
# Rows count:	167402
# Total count A:	83857
# Total count B:	83889
# Elapsed rate A:	3.882/s
# Elapsed rate B:	3.884/s
# Sample rate A:	125219.9/s
# Sample rate B:	125232.3/s
#
#
# Total coincidences:		334
# Single coincidences:		334
# Coincidence elapsed rate:	0.016/s (1/0:01:04s)
# Coincidence sample rate:	502.36/s

# %% [markdown]
# ## Calibration
#
# Energy scales have been calibrated with Cadmium-109 and Cobalt-57 sources. The calibration procedure can be found from the [whole spectra calibration](https://nbviewer.org/github/markomanninen/tandempiercerexperiment/blob/main/report_template/TPE%20report%20-%20whole%20spectra%20calibration.ipynb) notebook document.

# %%
from tpe.Stats import add_calibration_line, plot_peak_lines

gamma_photo_peak_cd109_kev = 88
# Cd-109 1μci
gamma_photo_peak_cd109_adc_a = 6181
gamma_photo_peak_cd109_adc_b = 6729
# Cd-109 10μci
#gamma_photo_peak_cd109_adc_a = 6261
#gamma_photo_peak_cd109_adc_b = 6453

gamma_photo_peak_co57_kev = 122
# C0-57 10μci
#gamma_photo_peak_co57_adc_a = 8532
#gamma_photo_peak_co57_adc_b = 8684

st.adc_calibrate_a(gamma_photo_peak_cd109_adc_a, gamma_photo_peak_cd109_kev)
st.adc_calibrate_b(gamma_photo_peak_cd109_adc_b, gamma_photo_peak_cd109_kev)

# %% [markdown]
# ## Plots
#
# ### Detector event timeline

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ### Pulse height spectrum
#
# Plot pulse height spectrum by bar graph, line graph, fitted curve and scatter version.
#
# Peaks are automatically detected by using `scipy.find_peaks` algorithm and then drawn to the plots.
#
# #### Channel A

# %%
st.reset_calibration_lines()
for peak in st.plot_channel_pulse_height_spectrum("A", bins=75, rolling=2)[:2]:
    st.add_calibration_line_a(round(peak, 1))
# Out:
# Maximum bins: 73

# %% [markdown]
# #### Channel B

# %%
for peak in st.plot_channel_pulse_height_spectrum("B", coincidences=False, bins=74, rolling=2)[:2]:
    st.add_calibration_line_b(round(peak, 1))
# Out:
# Maximum bins: 70

# %% [markdown]
# ### Coincidence time difference and scatter plots
#
# Time difference is retrieved when one of the detectors triggers and if there is a pulse in the other detector then a time distance between clicks is calculated by substracting the index of the pulses and multiplying that by the resolution of the oscilloscope. Typically, when there is a peak in the middle of the time difference histogram, it suggests that clicks were coincident and caused either by the same ray passing both detectors or two simultaneous rays coming in a stream.
#
# In the color scatter plot channels are distinguished by the red and blue colors. The size of the point relates to the time difference. Bigger the point, smaller is the time difference.

# %%
st.plot_time_histogram_and_scatter(hide_calibration=True)

# %% [markdown]
# ### Coincident spectra

# %%
st.plot_spectra(coincidences=True, log=True, bins=(16, 16), hide_calibration=True);

# %% [markdown]
# ## Stats

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_20_18_45\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output statistics head and tail:

# %%
d = st.stats[:]
d["Elapsed"] = d["Elapsed"].astype(int)
d["RateA"] = d["RateA"].astype(int)
d["RateB"] = d["RateB"].astype(int)
d
# Out:
#         RateCount                          Time  Elapsed  A  B   TotA   TotB  \
# 0               1 2022-02-20 16:45:22.651806116        0  1  0      1      0
# 1               2 2022-02-20 16:45:22.916088581        0  0  1      1      1
# 2               3 2022-02-20 16:45:22.964957476        0  1  0      2      1
# 3               4 2022-02-20 16:45:23.045741796        0  0  1      2      2
# 4               5 2022-02-20 16:45:23.120541811        0  1  0      3      2
# ...           ...                           ...      ... .. ..    ...    ...
# 167397     167437 2022-02-20 22:45:22.003200531    21599  1  0  83855  83887
# 167398     167438 2022-02-20 22:45:22.081689835    21599  0  1  83855  83888
# 167399     167439 2022-02-20 22:45:22.102774858    21599  1  0  83856  83888
# 167400     167440 2022-02-20 22:45:22.471090794    21599  0  1  83856  83889
# 167401     167441 2022-02-20 22:45:22.520675898    21600  1  0  83857  83889
#
#          RateA   RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  \
# 0       250000       0    0       0           0.000          0.000
# 1       125000  125000    0       0           0.000          0.000
# 2       166666   83333    0       0           0.000          0.000
# 3       125000  125000    0       0           0.000          0.000
# 4       150000  100000    0       0           0.000          0.000
# ...        ...     ...  ...     ...             ...            ...
# 167397  125203  125251    0     334           0.015        498.695
# 167398  125203  125252    0     334           0.015        498.692
# 167399  125203  125251    0     334           0.015        498.689
# 167400  125203  125252    0     334           0.015        498.686
# 167401  125203  125251    0     334           0.015        498.683
#
#         TimeDifference  APulseHeight  BPulseHeight  SampleSize  Chn
# 0                  nan         12063             0       0.000    0
# 1                  nan             0          6157       0.000    1
# 2                  nan          6930             0       0.000    0
# 3                  nan             0          4361       0.000    1
# 4                  nan          5903             0       0.000    0
# ...                ...           ...           ...         ...  ...
# 167397             nan          5133             0       0.670    0
# 167398             nan             0          3335       0.670    1
# 167399             nan          6160             0       0.670    0
# 167400             nan             0         10262       0.670    1
# 167401             nan          1540             0       0.670    0
#
# [167402 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
