# %% [markdown]
# # Tandem Piercer Experiment - Measurement report
#
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility (and optionally output current working directory name):

# %%
# %pylab inline
#print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_20*");
# Out:
# ../experiments\default_2022_2_20_0_9\statistics.csv
# ../experiments\default_2022_2_20_10_59\statistics.csv
# ../experiments\default_2022_2_20_18_45\statistics.csv

# %% [markdown]
# Output header, general settings, instrument details and trigger info for the selected measurement:

# %%
directory1 = "../experiments\default_2022_2_20_0_9"
get_report_header(directory1)
# Out:
# <h2>Background whole spectrum</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>SCA `(pos[:-1] & ~pos[1:]).nonzero()`</td></tr>                <tr><th>Sample size</th><td>8e-06s</td></tr>                <tr><th>Resolution</th><td>8e-09s</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>next</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.7          | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 842     | 576     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %%
st = Stats()
st.read_stats_dataframe(directory1);
st.print_basic_data();
# Out:
# Start time:	2022-02-19 22:09:49
# End time:	2022-02-20 04:09:49
# Time elapsed:	6:00:00
# Rows count:	161716
# Total count A:	81353
# Total count B:	81448
# Elapsed rate A:	3.8/s
# Elapsed rate B:	3.8/s
# Sample rate A:	125791.2/s
# Sample rate B:	125900.1/s
#
#
# Total coincidences:		1082
# Single coincidences:		1082
# Coincidence elapsed rate:	0.3/s
# Coincidence sample rate:	9615.4/s

# %%
from tpe.Stats import add_calibration_line, plot_peak_lines

gamma_photo_peak_cd109_kev = 88
gamma_photo_peak_cd109_adc_a = 6180.5
gamma_photo_peak_cd109_adc_b = 6728.5
gamma_photo_peak_co57_kev = 122

st.adc_calibrate_a(gamma_photo_peak_cd109_adc_a, gamma_photo_peak_cd109_kev)
st.adc_calibrate_b(gamma_photo_peak_cd109_adc_b, gamma_photo_peak_cd109_kev)

# %% [markdown]
# ### Detector clicks timeline

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ### Pulse height spectrum
#
# Plot pulse height spectrum by bar graph, line graph, fitted curve and scatter version.
#
# Peaks are automatically detected by using `scipy.find_peaks` algorithm and then drawn to the plots.
#
# #### Channel A

# %%
st.reset_calibration_lines()
for peak in st.plot_channel_pulse_height_spectrum("A", bins=74, rolling=2)[:2]:
    st.add_calibration_line_a(round(peak, 1))

# %% [markdown]
# #### Channel B

# %%
for peak in st.plot_channel_pulse_height_spectrum("B", coincidences=False, bins=74, rolling=2)[:2]:
    st.add_calibration_line_b(round(peak, 1))

# %% [markdown]
# ### Coincidence time difference and scatter plots
#
# Time difference is retrieved when one of the detectors triggers and if there is a pulse in the other detector then a time distance between clicks is calculated by substracting the index of the pulses and multiplying that by the resolution of the oscilloscope. Typically, when there is a peak in the middle of the time difference histogram, it suggests that clicks were coincident and caused either by the same ray passing both detectors or two simultaneous rays coming in a stream.
#
# In the color scatter plot channels are distinguished by the red and blue colors. The size of the point relates to the time difference. Bigger the point, smaller is the time difference.

# %%
st.plot_time_histogram_and_scatter(hide_calibration=True)

# %% [markdown]
# ### Coincident spectra

# %%
st.plot_spectra(coincidences=True, log=True, bins=(16, 16), hide_calibration=True);

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_20_0_9\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output statistics head and tail:

# %%
st.stats
# Out:
#         RateCount                          Time    Elapsed  A  B   TotA  \
# 0               1 2022-02-19 22:09:49.019852638      0.041  1  0      1
# 1               2 2022-02-19 22:09:49.042791128      0.064  0  1      1
# 2               3 2022-02-19 22:09:49.078694820      0.100  1  0      2
# 3               4 2022-02-19 22:09:49.089665413      0.111  0  1      2
# 4               5 2022-02-19 22:09:49.650166750      0.671  1  0      3
# ...           ...                           ...        ... .. ..    ...
# 161711     161764 2022-02-20 04:09:48.723165274 21,599.744  0  1  81351
# 161712     161765 2022-02-20 04:09:48.757740498 21,599.779  1  0  81352
# 161713     161766 2022-02-20 04:09:48.807199240 21,599.828  0  1  81352
# 161714     161767 2022-02-20 04:09:48.854353428 21,599.875  1  0  81353
# 161715     161768 2022-02-20 04:09:49.078265429 21,600.099  0  1  81353
#
#          TotB       RateA       RateB  Cnc  TotCnc  ElapsedCncRate  \
# 0           0 250,000.000       0.000    0       0           0.000
# 1           1 125,000.000 125,000.000    0       0           0.000
# 2           1 166,666.667  83,333.333    0       0           0.000
# 3           2 125,000.000 125,000.000    0       0           0.000
# 4           2 150,000.000 100,000.000    0       0           0.000
# ...       ...         ...         ...  ...     ...             ...
# 161711  81446 125,724.821 125,871.640    0    1082           0.050
# 161712  81446 125,725.590 125,870.862    0    1082           0.050
# 161713  81447 125,724.812 125,871.629    0    1082           0.050
# 161714  81447 125,725.581 125,870.851    0    1082           0.050
# 161715  81448 125,724.803 125,871.619    0    1082           0.050
#
#         SampleCncRate  TimeDifference  APulseHeight  BPulseHeight  SampleSize  \
# 0               0.000             nan          3336             0       0.000
# 1               0.000             nan             0         12314       0.000
# 2               0.000             nan          8213             0       0.000
# 3               0.000             nan             0          5900       0.000
# 4               0.000             nan          8727             0       0.000
# ...               ...             ...           ...           ...         ...
# 161711      1,672.189             nan             0          5900       0.647
# 161712      1,672.179             nan          2310             0       0.647
# 161713      1,672.168             nan             0         15649       0.647
# 161714      1,672.158             nan          2310             0       0.647
# 161715      1,672.148             nan             0          6670       0.647
#
#         Chn
# 0         0
# 1         1
# 2         0
# 3         1
# 4         0
# ...     ...
# 161711    1
# 161712    0
# 161713    1
# 161714    0
# 161715    1
#
# [161716 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
