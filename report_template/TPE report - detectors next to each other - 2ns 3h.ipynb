# %% [markdown]
# # Tandem Piercer Experiment - Measurement report

# %% [markdown]
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility and output current working directory name:

# %%
# %pylab inline
print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# Current directory: C:\Users\phtep\Documents\TandemPiercerExperiment\report_template

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_15*");
# Out:
# ../experiments\default_2022_2_15_0_27\statistics.csv
# ../experiments\default_2022_2_15_10_33\statistics.csv
# ../experiments\default_2022_2_15_15_27\statistics.csv
# ../experiments\default_2022_2_15_18_27\statistics.csv
# ../experiments\default_2022_2_15_21_31\statistics.csv
# ../experiments\default_2022_2_15_7_32\statistics.csv

# %% [markdown]
# Define a working experiment directory and get a report header:

# %%
directory = "../experiments\default_2022_2_15_15_27"
get_report_header(directory)
# Out:
# <h2>Detectors next to each other - Alternating trigger 2ns</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>4e-05s</td></tr>                <tr><th>Resolution</th><td>4e-09</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>next</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st.read_stats_dataframe(directory);
st.print_basic_data();
# Out:
# Start time:	2022-02-15 13:27:35
# End time:	2022-02-15 16:27:35
# Time elapsed:	3:00:00
# Rows count:	79564
# Total count A:	41395
# Total count B:	42309
# Elapsed rate A:	3.8/s
# Elapsed rate B:	3.9/s
# Sample rate A:	25000.0/s
# Sample rate B:	13888.9/s
#
#
# Total coincidences:		949
# Single coincidences:		607
# Coincidence elapsed rate:	0.2/s
# Coincidence sample rate:	892.9/s

# %% [markdown]
# ## Detector clicks in time

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ## Detector accumulated clicks and sample rates

# %%
st.plot_channel_totals_and_rates()

# %% [markdown]
# ## Detectors coincidence counts and rates

# %%
st.plot_coincidences_and_sample_rate()

# %%
st.plot_coincidences_and_sample_rate(elapsed = (4535, 4540))

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st.adc_calibrate_a(12500, 122)
st.adc_calibrate_b(12500, 122)

# %%
st.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st.plot_time_histogram_and_scatter(time_difference=100)

# %% [markdown]
# ## Coincidence spectra

# %%
st.plot_spectra(coincidences=True);

# %% [markdown]
# ## Channel spectra

# %%
st.fit_spectra(coincidences=False, log=True)

# %% [markdown]
# #### Data

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_15_15_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB      RateA  \
# 0     2022-02-15 13:27:35.377013445      0.062  1  0      1      0 25,000.000
# 1     2022-02-15 13:27:35.626347542      0.311  0  1      1      1 12,500.000
# 2     2022-02-15 13:27:35.644298792      0.329  1  0      2      1 16,666.667
# 3     2022-02-15 13:27:35.735056400      0.420  0  1      2      2 12,500.000
# 4     2022-02-15 13:27:36.086116076      0.771  1  0      3      2 15,000.000
# ...                             ...        ... .. ..    ...    ...        ...
# 79559 2022-02-15 16:27:34.413496494 10,799.098  1  0  41393  42307 13,003.745
# 79560 2022-02-15 16:27:34.866284847 10,799.551  0  1  41393  42308 13,003.581
# 79561 2022-02-15 16:27:34.945073843 10,799.630  1  0  41394  42308 13,003.732
# 79562 2022-02-15 16:27:35.112625599 10,799.797  0  1  41394  42309 13,003.569
# 79563 2022-02-15 16:27:35.353012562 10,800.038  1  0  41395  42309 13,003.719
#
#            RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0          0.000    0       0           0.000          0.000             nan
# 1     12,500.000    0       0           0.000          0.000             nan
# 2      8,333.333    0       0           0.000          0.000             nan
# 3     12,500.000    0       0           0.000          0.000             nan
# 4     10,000.000    0       0           0.000          0.000             nan
# ...          ...  ...     ...             ...            ...             ...
# 79559 13,290.881    0     949           0.088        298.131             nan
# 79560 13,291.028    0     949           0.088        298.128             nan
# 79561 13,290.861    0     949           0.088        298.124             nan
# 79562 13,291.008    0     949           0.088        298.120             nan
# 79563 13,290.841    0     949           0.088        298.116             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0         7,183.537         0.000          1       0.000    0
# 1             0.000    14,108.857          2       0.000    1
# 2         4,880.371         0.000          3       0.000    0
# 3             0.000    11,799.166          4       0.000    1
# 4         5,903.350         0.000          5       0.000    0
# ...             ...           ...        ...         ...  ...
# 79559     8,227.939         0.000      79579       3.183    0
# 79560         0.000    12,311.192      79580       3.183    1
# 79561     3,615.948         0.000      79581       3.183    0
# 79562         0.000     6,411.837      79582       3.183    1
# 79563     8,985.085         0.000      79583       3.183    0
#
# [79564 rows x 18 columns]

# %%
directory = "../experiments\default_2022_2_15_18_27"
get_report_header(directory)
# Out:
# <h2>Detectors next to each other - Alternating trigger 2ns</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>SCA `(pos[:-1] & ~pos[1:]).nonzero()`</td></tr>                <tr><th>Sample size</th><td>4e-05s</td></tr>                <tr><th>Resolution</th><td>4e-09</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>next</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st2 = Stats()
st2.read_stats_dataframe(directory);
st2.print_basic_data();
# Out:
# Start time:	2022-02-15 16:27:42
# End time:	2022-02-15 19:27:42
# Time elapsed:	3:00:00
# Rows count:	77841
# Total count A:	39186
# Total count B:	39234
# Elapsed rate A:	3.6/s
# Elapsed rate B:	3.6/s
# Sample rate A:	25000.0/s
# Sample rate B:	12665.0/s
#
#
# Total coincidences:		548
# Single coincidences:		548
# Coincidence elapsed rate:	1.9/s
# Coincidence sample rate:	6250.0/s

# %% [markdown]
# ### Detector clicks in time

# %%
st2.plot_channel_counts(sec=60)

# %% [markdown]
# ### Detector accumulated clicks and sample rates

# %%
st2.plot_channel_totals_and_rates()

# %% [markdown]
# ### Detectors coincidence counts and rates

# %%
st2.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st2.adc_calibrate_a(12500, 122)
st2.adc_calibrate_b(12500, 122)

# %% [markdown]
# #### Channel A

# %%
st2.plot_time_histogram_and_scatter(channel=0)

# %% [markdown]
# #### Channel B

# %%
st2.plot_time_histogram_and_scatter(channel=1)

# %% [markdown]
# #### Both channels A & B

# %%
st2.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st2.plot_time_histogram_and_scatter(time_difference=100)

# %% [markdown]
# ## Coincidence spectra

# %%
st2.plot_spectra(coincidences=True, log=False, bins=60);

# %% [markdown]
# ## Channel spectra with the fitted line

# %%
st2.fit_spectra(coincidences=False, log=True);

# %% [markdown]
# ### Data

# %%
st2.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_15_18_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st2.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB      RateA  \
# 0     2022-02-15 16:27:42.553601503      0.255  1  0      1      0 25,000.000
# 1     2022-02-15 16:27:42.745087385      0.447  0  1      1      1 12,500.000
# 2     2022-02-15 16:27:42.808917999      0.511  1  0      2      1 16,666.667
# 3     2022-02-15 16:27:42.836843491      0.539  1  1      3      2 18,750.000
# 4     2022-02-15 16:27:43.655651569      1.357  1  0      4      2 20,000.000
# ...                             ...        ... .. ..    ...    ...        ...
# 77836 2022-02-15 19:27:41.646379471 10,799.348  0  1  39184  39232 12,581.557
# 77837 2022-02-15 19:27:41.749104977 10,799.451  1  0  39185  39232 12,581.716
# 77838 2022-02-15 19:27:41.830887794 10,799.533  0  1  39185  39233 12,581.555
# 77839 2022-02-15 19:27:42.266721009 10,799.968  1  0  39186  39233 12,581.714
# 77840 2022-02-15 19:27:42.387399197 10,800.089  0  1  39186  39234 12,581.552
#
#            RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0          0.000    0       0           0.000          0.000             nan
# 1     12,500.000    0       0           0.000          0.000             nan
# 2      8,333.333    0       0           0.000          0.000             nan
# 3     12,500.000    1       1           1.857      6,250.000           7.000
# 4     10,000.000    0       1           0.737      5,000.000             nan
# ...          ...  ...     ...             ...            ...             ...
# 77836 12,596.969    0     548           0.051        175.957             nan
# 77837 12,596.807    0     548           0.051        175.955             nan
# 77838 12,596.966    0     548           0.051        175.952             nan
# 77839 12,596.805    0     548           0.051        175.950             nan
# 77840 12,596.964    0     548           0.051        175.948             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0              8213             0          1       0.000    0
# 1               256          8466          2       0.000    1
# 2              5390           256          3       0.000    0
# 3              2566         15136          4       0.000    1
# 4              5646             0          5       0.000    0
# ...             ...           ...        ...         ...  ...
# 77836             0         11288      77860       3.114    1
# 77837          8727             0      77861       3.114    0
# 77838             0          6670      77862       3.114    1
# 77839          3850           256      77863       3.115    0
# 77840             0         12314      77864       3.115    1
#
# [77841 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
