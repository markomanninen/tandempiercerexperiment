# %% [markdown]
# # Tandem Piercer Experiment - Measurement report

# %% [markdown]
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility and output current working directory name:

# %%
# %pylab inline
print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# Current directory: C:\Users\phtep\Documents\TandemPiercerExperiment\report_template

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_1*");
# Out:
# ../experiments\default_2022_2_13_15_53\statistics.csv
# ../experiments\default_2022_2_13_22_27\statistics.csv
# ../experiments\default_2022_2_13_3_52\statistics.csv
# ../experiments\default_2022_2_14_10_27\statistics.csv
# ../experiments\default_2022_2_14_18_27\statistics.csv
# ../experiments\default_2022_2_15_0_27\statistics.csv

# %% [markdown]
# Define a working experiment directory and get a report header:

# %%
directory = "../experiments\default_2022_2_13_22_27"
get_report_header(directory)
# Out:
# <h2>Detectors next to each other - No trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>None</td></tr>                <tr><th>Detector geometry</th><td>next</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1100</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st.read_stats_dataframe(directory);
st.print_basic_data();
# Out:
# Start time:	2022-02-13 20:27:22.136049509
# End time:	2022-02-14 02:27:21.932223320
# Time elapsed:	6:00:00
# Rows count:	122676
# Total count A:	66884
# Total count B:	68661
# Elapsed rate A:	3.1/s
# Elapsed rate B:	3.2/s
# Sample rate A:	36.2/s
# Sample rate B:	36.6/2
#
#
# Total coincidences:		7224
# Single coincidences:		5846
# Coincidence elapsed rate:	0.5/s
# Coincidence sample rate:	2.9/s

# %% [markdown]
# ## Detector clicks in time

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ## Detector accumulated clicks and sample rates

# %%
st.plot_channel_totals_and_rates()

# %% [markdown]
# ## Detectors coincidence counts and rates

# %%
st.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st.adc_calibrate_a(12500, 122)
st.adc_calibrate_b(12500, 122)

# %%
st.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st.plot_time_histogram_and_scatter(time_difference=0)

# %% [markdown]
# ## Coincidence spectra

# %%
st.plot_spectra(coincidences=True);

# %% [markdown]
# ## Channel spectra

# %%
st.fit_spectra(coincidences=False, log=True)

# %% [markdown]
# #### Data

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_13_22_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st.stats
# Out:
#                                 Time    Elapsed  A  B   TotA   TotB  RateA  \
# 0      2022-02-13 20:27:22.136049509      0.228  1  0      1      0 29.274
# 1      2022-02-13 20:27:22.321534634      0.414  1  0      2      0 31.526
# 2      2022-02-13 20:27:22.353448391      0.446  0  1      2      1 29.274
# 3      2022-02-13 20:27:22.445203304      0.538  1  0      3      1 36.162
# 4      2022-02-13 20:27:22.506041288      0.598  0  1      3      2 32.355
# ...                              ...        ... .. ..    ...    ...    ...
# 122671 2022-02-14 02:27:21.497562408 21,599.590  0  1  66882  68659 19.651
# 122672 2022-02-14 02:27:21.559397221 21,599.652  1  0  66883  68659 19.651
# 122673 2022-02-14 02:27:21.621055365 21,599.713  1  0  66884  68659 19.651
# 122674 2022-02-14 02:27:21.899310589 21,599.992  0  1  66884  68660 19.651
# 122675 2022-02-14 02:27:21.932223320 21,600.025  0  1  66884  68661 19.651
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0       0.000    0       0           0.000          0.000             nan
# 1       0.000    0       0           0.000          0.000             nan
# 2      14.637    0       0           0.000          0.000             nan
# 3      12.054    0       0           0.000          0.000             nan
# 4      21.570    0       0           0.000          0.000             nan
# ...       ...  ...     ...             ...            ...             ...
# 122671 20.173    0    7224           0.334          2.122             nan
# 122672 20.173    0    7224           0.334          2.122             nan
# 122673 20.173    0    7224           0.334          2.122             nan
# 122674 20.173    0    7224           0.334          2.122             nan
# 122675 20.173    0    7224           0.334          2.122             nan
#
#         APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0          1,032.093         0.000          7       0.034    0
# 1          1,032.528         0.000         13       0.063    0
# 2              0.000     1,030.506         14       0.068    0
# 3          3,087.194         0.000         17       0.083    0
# 4              0.000       516.584         19       0.093    0
# ...              ...           ...        ...         ...  ...
# 122671         0.000       514.613     697446   3,403.536    0
# 122672     4,118.467         0.000     697448   3,403.546    0
# 122673     8,742.795         0.000     697450   3,403.556    0
# 122674         0.000     3,850.560     697459   3,403.600    0
# 122675         0.000     2,824.073     697460   3,403.605    0
#
# [122676 rows x 18 columns]

# %%
directory = "../experiments\default_2022_2_14_10_27"
get_report_header(directory)
# Out:
# <h2>Detectors on top of each other - Alternating trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>next</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1100</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st2 = Stats()
st2.read_stats_dataframe(directory);
st2.print_basic_data();
# Out:
# Start time:	2022-02-14 08:27:35.551588774
# End time:	2022-02-14 14:27:35.478792906
# Time elapsed:	6:00:00
# Rows count:	70721
# Total count A:	41744
# Total count B:	42456
# Elapsed rate A:	1.9/s
# Elapsed rate B:	2.0/s
# Sample rate A:	204.9/s
# Sample rate B:	123.2/2
#
#
# Total coincidences:		8377
# Single coincidences:		6270
# Coincidence elapsed rate:	0.4/s
# Coincidence sample rate:	25.8/s

# %% [markdown]
# ### Detector clicks in time

# %%
st2.plot_channel_counts(sec=60)

# %% [markdown]
# ### Detector accumulated clicks and sample rates

# %%
st2.plot_channel_totals_and_rates()

# %% [markdown]
# ### Detectors coincidence counts and rates

# %%
st2.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st2.adc_calibrate_a(12500, 122)
st2.adc_calibrate_b(12500, 122)

# %% [markdown]
# #### Channel A

# %%
st2.plot_time_histogram_and_scatter(channel=0)

# %% [markdown]
# #### Channel B

# %%
st2.plot_time_histogram_and_scatter(channel=1)

# %% [markdown]
# #### Both channels A & B

# %%
st2.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st2.plot_time_histogram_and_scatter(time_difference=0)

# %% [markdown]
# ## Coincidence spectra

# %%
st2.plot_spectra(coincidences=True, log=True);

# %% [markdown]
# ## Channel spectra with the fitted line

# %%
st2.fit_spectra(coincidences=False, log=True);

# %% [markdown]
# ### Data

# %%
st2.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_14_10_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st2.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB   RateA  \
# 0     2022-02-14 08:27:35.551588774      0.359  1  0      1      0 204.918
# 1     2022-02-14 08:27:35.704148531      0.512  0  1      1      1 102.459
# 2     2022-02-14 08:27:35.879678965      0.687  1  0      2      1 136.612
# 3     2022-02-14 08:27:36.028280973      0.836  0  1      2      2 102.459
# 4     2022-02-14 08:27:36.166909456      0.974  1  0      3      2 122.951
# ...                             ...        ... .. ..    ...    ...     ...
# 70716 2022-02-14 14:27:33.765169621 21,598.573  1  1  41742  42454 117.746
# 70717 2022-02-14 14:27:34.084314346 21,598.892  0  1  41742  42455 117.745
# 70718 2022-02-14 14:27:34.699708700 21,599.507  1  0  41743  42455 117.746
# 70719 2022-02-14 14:27:35.124713182 21,599.932  0  1  41743  42456 117.744
# 70720 2022-02-14 14:27:35.478792906 21,600.286  1  0  41744  42456 117.746
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0       0.000    0       0           0.000          0.000             nan
# 1     102.459    0       0           0.000          0.000             nan
# 2      68.306    0       0           0.000          0.000             nan
# 3     102.459    0       0           0.000          0.000             nan
# 4      81.967    0       0           0.000          0.000             nan
# ...       ...  ...     ...             ...            ...             ...
# 70716 119.755    1    8377           0.388         23.630             nan
# 70717 119.756    0    8377           0.388         23.630             nan
# 70718 119.754    0    8377           0.388         23.629             nan
# 70719 119.756    0    8377           0.388         23.629             nan
# 70720 119.754    0    8377           0.388         23.629             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0             0.000         0.000          1       0.005    0
# 1             0.000         0.000          2       0.010    1
# 2         2,570.403         0.000          3       0.015    0
# 3             0.000         0.000          4       0.020    1
# 4             0.000         0.000          5       0.024    0
# ...             ...           ...        ...         ...  ...
# 70716         0.000     4,104.205      72645     354.508    0
# 70717         0.000         0.000      72646     354.512    1
# 70718       519.375         0.000      72647     354.517    0
# 70719         0.000     1,282.384      72648     354.522    1
# 70720       517.966         0.000      72649     354.527    0
#
# [70721 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
