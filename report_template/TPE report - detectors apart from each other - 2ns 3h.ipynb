# %% [markdown]
# # Tandem Piercer Experiment - Measurement report

# %% [markdown]
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility and output current working directory name:

# %%
# %pylab inline
print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# Current directory: C:\Users\phtep\Documents\TandemPiercerExperiment\report_template

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_15*");
# Out:
# ../experiments\default_2022_2_15_0_27\statistics.csv
# ../experiments\default_2022_2_15_10_33\statistics.csv
# ../experiments\default_2022_2_15_15_27\statistics.csv
# ../experiments\default_2022_2_15_18_27\statistics.csv
# ../experiments\default_2022_2_15_7_32\statistics.csv

# %% [markdown]
# Define a working experiment directory and get a report header:

# %%
directory = "../experiments\default_2022_2_15_10_33"
get_report_header(directory)
# Out:
# <h2>Detectors apart from each other - Alternating trigger 2ns</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>SCA `(pos[:-1] & ~pos[1:]).nonzero()`</td></tr>                <tr><th>Sample size</th><td>4e-05s</td></tr>                <tr><th>Resolution</th><td>4e-09</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>apart</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st.read_stats_dataframe(directory);
st.print_basic_data();
# Out:
# Start time:	2022-02-15 08:33:06
# End time:	2022-02-15 11:33:06
# Time elapsed:	3:00:00
# Rows count:	83235
# Total count A:	41666
# Total count B:	41661
# Elapsed rate A:	3.9/s
# Elapsed rate B:	3.9/s
# Sample rate A:	25000.0/s
# Sample rate B:	12512.7/s
#
#
# Total coincidences:		66
# Single coincidences:		66
# Coincidence elapsed rate:	0.0/s
# Coincidence sample rate:	22.6/s

# %% [markdown]
# ## Detector clicks in time

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ## Detector accumulated clicks and sample rates

# %%
st.plot_channel_totals_and_rates()

# %% [markdown]
# ## Detectors coincidence counts and rates

# %%
st.plot_coincidences_and_sample_rate()

# %%
st.plot_coincidences_and_sample_rate(elapsed = (1500, 2500))

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st.adc_calibrate_a(12500, 122)
st.adc_calibrate_b(12500, 122)

# %%
st.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st.plot_time_histogram_and_scatter(time_difference=100)

# %% [markdown]
# ## Coincidence spectra

# %%
st.plot_spectra(coincidences=True);

# %% [markdown]
# ## Channel spectra

# %%
st.fit_spectra(coincidences=False, log=True)

# %% [markdown]
# #### Data

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_15_10_33\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB      RateA  \
# 0     2022-02-15 08:33:06.541378021      0.061  1  0      1      0 25,000.000
# 1     2022-02-15 08:33:06.794700623      0.314  0  1      1      1 12,500.000
# 2     2022-02-15 08:33:06.948290110      0.468  1  0      2      1 16,666.667
# 3     2022-02-15 08:33:07.125813484      0.645  0  1      2      2 12,500.000
# 4     2022-02-15 08:33:07.498816967      1.018  1  0      3      2 15,000.000
# ...                             ...        ... .. ..    ...    ...        ...
# 83230 2022-02-15 11:33:06.129727364 10,799.649  1  0  41664  41659 12,513.365
# 83231 2022-02-15 11:33:06.251400948 10,799.771  0  1  41664  41660 12,513.215
# 83232 2022-02-15 11:33:06.280324936 10,799.800  1  0  41665  41660 12,513.365
# 83233 2022-02-15 11:33:06.396053553 10,799.916  0  1  41665  41661 12,513.214
# 83234 2022-02-15 11:33:06.846807241 10,800.366  1  0  41666  41661 12,513.364
#
#            RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0          0.000    0       0           0.000          0.000             nan
# 1     12,500.000    0       0           0.000          0.000             nan
# 2      8,333.333    0       0           0.000          0.000             nan
# 3     12,500.000    0       0           0.000          0.000             nan
# 4     10,000.000    0       0           0.000          0.000             nan
# ...          ...  ...     ...             ...            ...             ...
# 83230 12,511.863    0      66           0.006         19.822             nan
# 83231 12,512.013    0      66           0.006         19.822             nan
# 83232 12,511.863    0      66           0.006         19.822             nan
# 83233 12,512.013    0      66           0.006         19.822             nan
# 83234 12,511.863    0      66           0.006         19.821             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0              2310           256          1       0.000    0
# 1                 0          6670          2       0.000    1
# 2              5903           256          3       0.000    0
# 3                 0          8979          4       0.000    1
# 4              1283           256          5       0.000    0
# ...             ...           ...        ...         ...  ...
# 83230         11037           256      83239       3.330    0
# 83231             0          2308      83240       3.330    1
# 83232         11037             0      83241       3.330    0
# 83233             0          5131      83242       3.330    1
# 83234          5390             0      83243       3.330    0
#
# [83235 rows x 18 columns]

# %%
directory = "../experiments\default_2022_2_15_7_32"
get_report_header(directory)
# Out:
# <h2>Detectors apart from each other - Alternating trigger 2ns</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>4e-05s</td></tr>                <tr><th>Resolution</th><td>4e-09</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>apart</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4            |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st2 = Stats()
st2.read_stats_dataframe(directory);
st2.print_basic_data();
# Out:
# Start time:	2022-02-15 05:32:58
# End time:	2022-02-15 08:32:58
# Time elapsed:	3:00:00
# Rows count:	80479
# Total count A:	41598
# Total count B:	42518
# Elapsed rate A:	3.9/s
# Elapsed rate B:	3.9/s
# Sample rate A:	25000.0/s
# Sample rate B:	16666.7/s
#
#
# Total coincidences:		102
# Single coincidences:		73
# Coincidence elapsed rate:	0.0/s
# Coincidence sample rate:	121.4/s

# %% [markdown]
# ### Detector clicks in time

# %%
st2.plot_channel_counts(sec=60)

# %% [markdown]
# ### Detector accumulated clicks and sample rates

# %%
st2.plot_channel_totals_and_rates()

# %% [markdown]
# ### Detectors coincidence counts and rates

# %%
st2.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st2.adc_calibrate_a(12500, 122)
st2.adc_calibrate_b(12500, 122)

# %% [markdown]
# #### Channel A

# %%
st2.plot_time_histogram_and_scatter(channel=0)

# %% [markdown]
# #### Channel B

# %%
st2.plot_time_histogram_and_scatter(channel=1)

# %% [markdown]
# #### Both channels A & B

# %%
st2.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st2.plot_time_histogram_and_scatter(time_difference=100)

# %% [markdown]
# ## Coincidence spectra

# %%
st2.plot_spectra(coincidences=True, log=False);

# %% [markdown]
# ## Channel spectra with the fitted line

# %%
st2.fit_spectra(coincidences=False, log=True);

# %% [markdown]
# ### Data

# %%
st2.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_15_7_32\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st2.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB      RateA  \
# 0     2022-02-15 05:32:58.759981394      0.132  1  0      1      0 25,000.000
# 1     2022-02-15 05:32:58.905580521      0.277  0  1      1      1 12,500.000
# 2     2022-02-15 05:32:59.102085590      0.474  1  0      2      1 16,666.667
# 3     2022-02-15 05:32:59.130977631      0.503  0  1      2      2 12,500.000
# 4     2022-02-15 05:32:59.199792624      0.571  1  0      3      2 15,000.000
# ...                             ...        ... .. ..    ...    ...        ...
# 80474 2022-02-15 08:32:57.973351479 10,799.345  0  1  41596  42516 12,919.938
# 80475 2022-02-15 08:32:58.382258892 10,799.754  1  0  41597  42516 12,920.088
# 80476 2022-02-15 08:32:58.536844015 10,799.909  0  1  41597  42517 12,919.928
# 80477 2022-02-15 08:32:58.619623184 10,799.991  1  0  41598  42517 12,920.078
# 80478 2022-02-15 08:32:58.962266207 10,800.334  0  1  41598  42518 12,919.918
#
#            RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0          0.000    0       0           0.000          0.000             nan
# 1     12,500.000    0       0           0.000          0.000             nan
# 2      8,333.333    0       0           0.000          0.000             nan
# 3     12,500.000    0       0           0.000          0.000             nan
# 4     10,000.000    0       0           0.000          0.000             nan
# ...          ...  ...     ...             ...            ...             ...
# 80474 13,205.695    0     102           0.009         31.682             nan
# 80475 13,205.531    0     102           0.009         31.681             nan
# 80476 13,205.678    0     102           0.009         31.681             nan
# 80477 13,205.514    0     102           0.009         31.681             nan
# 80478 13,205.660    0     102           0.009         31.680             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0         8,716.489         0.000          1       0.000    0
# 1             0.000     8,463.218          2       0.000    1
# 2         7,696.426         0.000          3       0.000    0
# 3             0.000     4,103.042          4       0.000    1
# 4         3,600.517         0.000          5       0.000    0
# ...             ...           ...        ...         ...  ...
# 80474         0.000     2,308.556      80488       3.220    1
# 80475     5,402.682         0.000      80489       3.220    0
# 80476         0.000    15,389.677      80490       3.220    1
# 80477     1,304.763         0.000      80491       3.220    0
# 80478         0.000     7,952.371      80492       3.220    1
#
# [80479 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
