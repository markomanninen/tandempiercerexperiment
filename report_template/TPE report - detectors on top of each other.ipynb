# %% [markdown]
# # Tandem Piercer Experiment - Measurement report

# %% [markdown]
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility and output current working directory name:

# %%
# %pylab inline
print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# Current directory: C:\Users\phtep\Documents\TandemPiercerExperiment\report_template

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_13*");
# Out:
# ../experiments\default_2022_2_13_15_53\statistics.csv
# ../experiments\default_2022_2_13_22_27\statistics.csv
# ../experiments\default_2022_2_13_3_52\statistics.csv

# %% [markdown]
# Define a working experiment directory and get a report header:

# %%
directory = "../experiments\default_2022_2_13_3_52"
get_report_header(directory)
# Out:
# <h2>Detectors on top of each other - No trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>None</td></tr>                <tr><th>Detector geometry</th><td>top</td></tr>                <tr><th>Front detector</th><td>A</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st.read_stats_dataframe(directory);
st.print_basic_data();
# Out:
# Start time:	2022-02-13 01:52:59
# End time:	2022-02-13 07:52:58
# Time elapsed:	5:59:59
# Rows count:	122431
# Total count A:	67381
# Total count B:	67975
# Elapsed rate A:	3.1/s
# Elapsed rate B:	3.1/s
# Sample rate A:	28.4/s
# Sample rate B:	21.4/s
#
#
# Total coincidences:		7142
# Single coincidences:		5792
# Coincidence elapsed rate:	0.5/s
# Coincidence sample rate:	3.2/s

# %% [markdown]
# ## Detector clicks in time

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ## Detector accumulated clicks and sample rates

# %%
st.plot_channel_totals_and_rates()

# %% [markdown]
# ## Detectors coincidence counts and rates

# %%
st.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st.adc_calibrate_a(12500, 122)
st.adc_calibrate_b(12500, 122)

# %%
st.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st.plot_time_histogram_and_scatter(time_difference=0)

# %% [markdown]
# ## Coincidence spectra

# %%
st.plot_spectra(coincidences=True, bins=77);

# %% [markdown]
# ## Channel spectra

# %%
st.fit_spectra(coincidences=False, log=True, bins=77)

# %% [markdown]
# #### Data

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_13_3_52\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st.stats
# Out:
#                                 Time    Elapsed  A  B   TotA   TotB  RateA  \
# 0      2022-02-13 01:52:59.282012463      0.509  0  1      0      1  0.000
# 1      2022-02-13 01:52:59.435602427      0.662  1  0      1      1  9.758
# 2      2022-02-13 01:52:59.466519594      0.693  0  1      1      2  9.314
# 3      2022-02-13 01:52:59.590188742      0.817  1  0      2      2 15.763
# 4      2022-02-13 01:52:59.868479252      1.095  1  0      3      2 17.564
# ...                              ...        ... .. ..    ...    ...    ...
# 122426 2022-02-13 07:52:58.377555370 21,599.604  0  1  67378  67972 19.822
# 122427 2022-02-13 07:52:58.439390898 21,599.666  1  1  67379  67973 19.822
# 122428 2022-02-13 07:52:58.565055370 21,599.792  2  0  67381  67973 19.823
# 122429 2022-02-13 07:52:58.687725782 21,599.914  0  1  67381  67974 19.822
# 122430 2022-02-13 07:52:58.750841379 21,599.977  0  1  67381  67975 19.822
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0      12.807    0       0           0.000          0.000             nan
# 1       9.758    0       0           0.000          0.000             nan
# 2      18.629    0       0           0.000          0.000             nan
# 3      15.763    0       0           0.000          0.000             nan
# 4      11.710    0       0           0.000          0.000             nan
# ...       ...  ...     ...             ...            ...             ...
# 122426 19.997    0    7141           0.331          2.101             nan
# 122427 19.997    1    7142           0.331          2.101      -3,392.000
# 122428 19.997    0    7142           0.331          2.101             nan
# 122429 19.997    0    7142           0.331          2.101             nan
# 122430 19.997    0    7142           0.331          2.101             nan
#
#         APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0              0.000     4,617.589         16       0.078    0
# 1          4,881.299         0.000         21       0.102    0
# 2              0.000       513.793         22       0.107    0
# 3          7,705.171         0.000         26       0.127    0
# 4          6,677.659         0.000         35       0.171    0
# ...              ...           ...        ...         ...  ...
# 122426         0.000       513.230     696555   3,399.188    0
# 122427     4,116.342     3,335.179     696557   3,399.198    0
# 122428     7,196.036         0.000     696561   3,399.218    0
# 122429         0.000     7,184.640     696565   3,399.237    0
# 122430         0.000     4,617.486     696567   3,399.247    0
#
# [122431 rows x 18 columns]

# %%
directory = "../experiments\default_2022_2_13_15_53"
get_report_header(directory)
# Out:
# <h2>Detectors on top of each other - Alternating trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>top</td></tr>                <tr><th>Front detector</th><td>A</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st2 = Stats()
st2.read_stats_dataframe(directory);
st2.print_basic_data();
# Out:
# Start time:	2022-02-13 13:53:11
# End time:	2022-02-13 19:53:11
# Time elapsed:	6:00:00
# Rows count:	69908
# Total count A:	41389
# Total count B:	41427
# Elapsed rate A:	1.9/s
# Elapsed rate B:	1.9/s
# Sample rate A:	204.9/s
# Sample rate B:	123.9/s
#
#
# Total coincidences:		7966
# Single coincidences:		5996
# Coincidence elapsed rate:	1.2/s
# Coincidence sample rate:	51.2/s

# %% [markdown]
# ### Detector clicks in time

# %%
st2.plot_channel_counts(sec=60)

# %% [markdown]
# ### Detector accumulated clicks and sample rates

# %%
st2.plot_channel_totals_and_rates()

# %% [markdown]
# ### Detectors coincidence counts and rates

# %%
st2.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st2.adc_calibrate_a(12500, 122)
st2.adc_calibrate_b(12500, 122)

# %% [markdown]
# #### Channel A

# %%
st2.plot_time_histogram_and_scatter(channel=0)

# %% [markdown]
# #### Channel B

# %%
st2.plot_time_histogram_and_scatter(channel=1)

# %% [markdown]
# #### Both channels A & B

# %%
st2.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st2.plot_time_histogram_and_scatter(time_difference=0)

# %% [markdown]
# ## Coincidence spectra

# %%
st2.plot_spectra(coincidences=True, log=True);

# %% [markdown]
# ## Channel spectra with the fitted line

# %%
st2.fit_spectra(coincidences=False, log=True);

# %% [markdown]
# ### Data

# %%
st2.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_13_15_53\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st2.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB   RateA  \
# 0     2022-02-13 13:53:11.929133654      0.249  1  0      1      0 204.918
# 1     2022-02-13 13:53:12.057788372      0.378  0  1      1      1 102.459
# 2     2022-02-13 13:53:12.249814034      0.570  1  0      2      1 136.612
# 3     2022-02-13 13:53:12.514077902      0.834  1  1      3      2 153.689
# 4     2022-02-13 13:53:12.766441345      1.087  1  0      4      2 163.934
# ...                             ...        ... .. ..    ...    ...     ...
# 69903 2022-02-13 19:53:10.146523952 21,598.467  0  1  41387  41424 118.112
# 69904 2022-02-13 19:53:11.157821178 21,599.478  1  0  41388  41424 118.114
# 69905 2022-02-13 19:53:11.386209249 21,599.706  0  2  41388  41426 118.112
# 69906 2022-02-13 19:53:11.552067041 21,599.872  1  0  41389  41426 118.113
# 69907 2022-02-13 19:53:11.713639259 21,600.034  0  1  41389  41427 118.112
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0       0.000    0       0           0.000          0.000             nan
# 1     102.459    0       0           0.000          0.000             nan
# 2      68.306    0       0           0.000          0.000             nan
# 3     102.459    1       1           1.199         51.230      -3,877.000
# 4      81.967    0       1           0.920         40.984             nan
# ...       ...  ...     ...             ...            ...             ...
# 69903 118.218    0    7966           0.369         22.734             nan
# 69904 118.216    0    7966           0.369         22.733             nan
# 69905 118.220    0    7966           0.369         22.733             nan
# 69906 118.219    0    7966           0.369         22.733             nan
# 69907 118.220    0    7966           0.369         22.733             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0             0.000         0.000          1       0.005    0
# 1             0.000         0.000          2       0.010    1
# 2         2,316.682         0.000          3       0.015    0
# 3         7,449.604     2,052.282          4       0.020    1
# 4         1,033.783         0.000          5       0.024    0
# ...             ...           ...        ...         ...  ...
# 69903         0.000     1,795.589      71804     350.404    1
# 69904         0.000         0.000      71805     350.408    0
# 69905         0.000    17,446.126      71806     350.413    1
# 69906         0.000         0.000      71807     350.418    0
# 69907         0.000         0.000      71808     350.423    1
#
# [69908 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
