# %% [markdown]
# # Tandem Piercer Experiment - Measurement report

# %% [markdown]
# Load Python libraries:

# %%
import os
from tpe.Stats import Stats
from tpe.functions import md, load_styles, get_report_header

# %% [markdown]
# Load inline graphics utility and output current working directory name:

# %%
# %pylab inline
print("\nCurrent directory: %s" % os.getcwd())
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# Current directory: C:\Users\phtep\Documents\TandemPiercerExperiment\report_template

# %% [markdown]
# Initialize statistic class and output experiment statistic files to use in this report:

# %%
st = Stats()
st.print_experiment_stat_files("../experiments/default_2022_2_1[4,5]*");
# Out:
# ../experiments\default_2022_2_14_10_27\statistics.csv
# ../experiments\default_2022_2_14_18_27\statistics.csv
# ../experiments\default_2022_2_15_0_27\statistics.csv
# ../experiments\default_2022_2_15_10_33\statistics.csv
# ../experiments\default_2022_2_15_15_27\statistics.csv
# ../experiments\default_2022_2_15_18_27\statistics.csv
# ../experiments\default_2022_2_15_21_31\statistics.csv
# ../experiments\default_2022_2_15_7_32\statistics.csv

# %% [markdown]
# Define a working experiment directory and get a report header:

# %%
directory = "../experiments\default_2022_2_14_18_27"
get_report_header(directory)
# Out:
# <h2>Detectors apart from each other - No trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>None</td></tr>                <tr><th>Detector geometry</th><td>apart</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.75         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st.read_stats_dataframe(directory);
st.print_basic_data();
# Out:
# Start time:	2022-02-14 16:27:15
# End time:	2022-02-14 22:27:14
# Time elapsed:	6:00:00
# Rows count:	132126
# Total count A:	75560
# Total count B:	71030
# Elapsed rate A:	3.5/s
# Elapsed rate B:	3.3/s
# Sample rate A:	39.4/s
# Sample rate B:	24.5/s
#
#
# Total coincidences:		13536
# Single coincidences:		6162
# Coincidence elapsed rate:	1.1/s
# Coincidence sample rate:	6.9/s

# %% [markdown]
# ## Detector clicks in time

# %%
st.plot_channel_counts(sec=60)

# %% [markdown]
# ## Detector accumulated clicks and sample rates

# %%
st.plot_channel_totals_and_rates()

# %% [markdown]
# ## Detectors coincidence counts and rates

# %%
st.plot_coincidences_and_sample_rate()

# %%
st.plot_coincidences_and_sample_rate(elapsed = (16236, 16238))

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st.adc_calibrate_a(12500, 122)
st.adc_calibrate_b(12500, 122)

# %%
st.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st.plot_time_histogram_and_scatter(time_difference=10)

# %% [markdown]
# ## Coincidence spectra

# %%
st.plot_spectra(coincidences=True);

# %% [markdown]
# ## Channel spectra

# %%
st.fit_spectra(coincidences=False, log=True)

# %% [markdown]
# #### Data

# %%
st.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_14_18_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st.stats
# Out:
#                                 Time    Elapsed  A  B   TotA   TotB  RateA  \
# 0      2022-02-14 16:27:15.369297504      0.446  1  0      1      0 14.637
# 1      2022-02-14 16:27:15.494962454      0.571  1  0      2      0 22.769
# 2      2022-02-14 16:27:15.556795597      0.633  1  0      3      0 30.738
# 3      2022-02-14 16:27:15.617664337      0.694  1  0      4      0 37.258
# 4      2022-02-14 16:27:15.741333961      0.818  1  0      5      0 39.407
# ...                              ...        ... .. ..    ...    ...    ...
# 132121 2022-02-14 22:27:13.801954746 21,598.878  1  0  75556  71028 22.183
# 132122 2022-02-14 22:27:14.047331095 21,599.124  2  0  75558  71028 22.183
# 132123 2022-02-14 22:27:14.172963381 21,599.249  0  2  75558  71030 22.183
# 132124 2022-02-14 22:27:14.387388229 21,599.464  1  0  75559  71030 22.183
# 132125 2022-02-14 22:27:14.944067478 21,600.021  1  0  75560  71030 22.183
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0       0.000    0       0           0.000          0.000             nan
# 1       0.000    0       0           0.000          0.000             nan
# 2       0.000    0       0           0.000          0.000             nan
# 3       0.000    0       0           0.000          0.000             nan
# 4       0.000    0       0           0.000          0.000             nan
# ...       ...  ...     ...             ...            ...             ...
# 132121 20.853    0   13536           0.627          3.974             nan
# 132122 20.853    0   13536           0.627          3.974             nan
# 132123 20.854    0   13536           0.627          3.974             nan
# 132124 20.853    0   13536           0.627          3.974             nan
# 132125 20.853    0   13536           0.627          3.974             nan
#
#         APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0          5,135.304         0.000         14       0.068    0
# 1          2,312.048         0.000         18       0.088    0
# 2         12,579.354         0.000         20       0.098    0
# 3            514.869         0.000         22       0.107    0
# 4          6,933.814         0.000         26       0.127    0
# ...              ...           ...        ...         ...  ...
# 132121     9,249.266         0.000     697966   3,406.074    0
# 132122     3,345.421         0.000     697974   3,406.113    0
# 132123         0.000    10,263.382     697978   3,406.133    0
# 132124     8,480.009         0.000     697985   3,406.167    0
# 132125     2,834.443         0.000     698003   3,406.255    0
#
# [132126 rows x 18 columns]

# %%
directory = "../experiments\default_2022_2_15_0_27"
get_report_header(directory)
# Out:
# <h2>Detectors apart from each other - Alternating trigger long run</h2><h3>General settings</h3>                <table>                <tr><th>Pulse source</th><td>Background</td></tr>                <tr><th>Pulse detection</th><td>RAW `scipy.find_peak(width=1, distance=1, threshold=0)`</td></tr>                <tr><th>Sample size</th><td>0.00488s</td></tr>                <tr><th>Resolution</th><td>4.88e-07</td></tr>                <tr><th>PicoScope trigger</th><td>simple, alternate: True </td></tr>                <tr><th>Detector geometry</th><td>apart</td></tr>                <tr><th>Front detector</th><td>na</td></tr>                <tr><th>PMT High Voltage</th><td>-1000</td></tr>                </table>
# <h3>SCA instrument details</h3>
# |             | Detector A   | Detector B   |
# |:------------|:-------------|:-------------|
# | Sca Model   | Ortec 490B   | Ortec 490B   |
# | Coarse Gain | 4.0          | 4.0          |
# | Fine Gain   | 3.35         | 10.0         |
# | Mode        | diff         | diff         |
# | Window      | 10.0         | 10.0         |
# | Lower Level | 0.75         | 0.4          |
# <h3>ADC limits for PicoScope channels</h3>
# |                 | A (0)   | B (1)   | C (2)   | D (3)   |
# |:----------------|:--------|:--------|:--------|:--------|
# | Voltage range   | 10V     | 10V     | 20V     | 20V     |
# | ADC low limits  | 4096    | 4096    | 500     | 500     |
# | ADC high limits | 32768   | 32768   | 19661   | 19661   |
# <h3>PicoScope channel map</h3>
# |                        |   Detector A |   Detector B |
# |:-----------------------|-------------:|-------------:|
# | Sca Square Pulse Index |            0 |            1 |
# | Raw Pulse Index        |            2 |            3 |
# <h3>PicoScope trigger details</h3>            <table>            <tr><th>Channel (start)</th><td>0</td></tr>            <tr><th>Delay</th><td>0</td></tr>            <tr><th>Direction</th><td>2</td></tr>            <tr><th>Threshold</th><td>16384</td></tr>            </table>

# %% [markdown]
# ### Experiment statistics
#
# Read statistics from the experiment and output basic data:

# %%
st2 = Stats()
st2.read_stats_dataframe(directory);
st2.print_basic_data();
# Out:
# Start time:	2022-02-14 22:27:21
# End time:	2022-02-15 04:27:21
# Time elapsed:	6:00:00
# Rows count:	72887
# Total count A:	43641
# Total count B:	42918
# Elapsed rate A:	2.0/s
# Elapsed rate B:	2.0/s
# Sample rate A:	204.9/s
# Sample rate B:	134.0/s
#
#
# Total coincidences:		8094
# Single coincidences:		6270
# Coincidence elapsed rate:	0.7/s
# Coincidence sample rate:	29.3/s

# %% [markdown]
# ### Detector clicks in time

# %%
st2.plot_channel_counts(sec=60)

# %% [markdown]
# ### Detector accumulated clicks and sample rates

# %%
st2.plot_channel_totals_and_rates()

# %% [markdown]
# ### Detectors coincidence counts and rates

# %%
st2.plot_coincidences_and_sample_rate()

# %% [markdown]
# ## Coincidence time histrogram and scatter plot
#
# Set calibrated values, ADC corresponding to kilo-electronvolts:

# %%
st2.adc_calibrate_a(12500, 122)
st2.adc_calibrate_b(12500, 122)

# %% [markdown]
# #### Channel A

# %%
st2.plot_time_histogram_and_scatter(channel=0)

# %% [markdown]
# #### Channel B

# %%
st2.plot_time_histogram_and_scatter(channel=1)

# %% [markdown]
# #### Both channels A & B

# %%
st2.plot_time_histogram_and_scatter()

# %% [markdown]
# ### Only coincidences where time difference is zero

# %%
st2.plot_time_histogram_and_scatter(time_difference=10)

# %% [markdown]
# ## Coincidence spectra

# %%
st2.plot_spectra(coincidences=True, log=True);

# %% [markdown]
# ## Channel spectra with the fitted line

# %%
st2.fit_spectra(coincidences=False, log=True);

# %% [markdown]
# ### Data

# %%
st2.print_stats_link()
# Out:
# <br/><center><h3>Download csv file: <a target='_blank' href='https://github.com/markomanninen/tandempiercerexperiment/raw/main/experiments\default_2022_2_15_0_27\statistics.csv'>statistics.csv</a></h3></center>

# %% [markdown]
# Output head and tail of the statistics data:

# %%
st2.stats
# Out:
#                                Time    Elapsed  A  B   TotA   TotB   RateA  \
# 0     2022-02-14 22:27:21.802111387      0.357  1  0      1      0 204.918
# 1     2022-02-14 22:27:21.867935181      0.422  0  1      1      1 102.459
# 2     2022-02-14 22:27:21.921792030      0.476  1  0      2      1 136.612
# 3     2022-02-14 22:27:22.121919870      0.676  0  1      2      2 102.459
# 4     2022-02-14 22:27:22.570749044      1.125  1  0      3      2 122.951
# ...                             ...        ... .. ..    ...    ...     ...
# 72882 2022-02-15 04:27:20.839425802 21,599.394  1  1  43638  42916 120.023
# 72883 2022-02-15 04:27:21.100727797 21,599.655  1  0  43639  42916 120.024
# 72884 2022-02-15 04:27:21.211431265 21,599.766  1  1  43640  42917 120.026
# 72885 2022-02-15 04:27:21.435829401 21,599.990  1  0  43641  42917 120.027
# 72886 2022-02-15 04:27:21.612358093 21,600.167  0  1  43641  42918 120.025
#
#         RateB  Cnc  TotCnc  ElapsedCncRate  SampleCncRate  TimeDifference  \
# 0       0.000    0       0           0.000          0.000             nan
# 1     102.459    0       0           0.000          0.000             nan
# 2      68.306    0       0           0.000          0.000             nan
# 3     102.459    0       0           0.000          0.000             nan
# 4      81.967    0       0           0.000          0.000             nan
# ...       ...  ...     ...             ...            ...             ...
# 72882 118.037    1    8093           0.375         22.259             nan
# 72883 118.036    0    8093           0.375         22.259             nan
# 72884 118.037    1    8094           0.375         22.261             nan
# 72885 118.035    0    8094           0.375         22.261             nan
# 72886 118.037    0    8094           0.375         22.261             nan
#
#        APulseHeight  BPulseHeight  RateCount  SampleSize  Chn
# 0             0.000         0.000          1       0.005    0
# 1             0.000         0.000          2       0.010    1
# 2             0.000         0.000          3       0.015    0
# 3             0.000         0.000          4       0.020    1
# 4             0.000         0.000          5       0.024    0
# ...             ...           ...        ...         ...  ...
# 72882     1,549.651         0.000      74504     363.580    1
# 72883         0.000         0.000      74505     363.584    0
# 72884    13,100.648         0.000      74506     363.589    1
# 72885     2,062.549         0.000      74507     363.594    0
# 72886         0.000     1,539.666      74508     363.599    1
#
# [72887 rows x 18 columns]

# %%
load_styles("../report.css")
# Out:
# <style>/* Notebook unstylings */
#
# .rendered_html table,
# .rendered_html tr,
# .rendered_html th,
# .rendered_html td {
#     border: 0
# }
#
# /* General table styles */
#
# table {
#     color: black;
#     border: 0;
#     margin: 1.5em auto;
#     border-bottom: 1px solid #999;
#     border-collapse: collapse;
#     -webkit-border-top-left-radius: 8px;
#     -webkit-border-top-right-radius: 8px;
#     -moz-border-radius: 8px 8px 0 0;
#     border-radius: 8px 8px 0 0;
#     background: #444;
# }
#
# table caption {
#     margin-bottom: .75em;
#     text-align: center;
#     font-style: italic;
# }
#
# table td {
#     -moz-transition: background 0.2s linear;
#     -o-transition: background 0.2s linear;
#     transition: background 0.2s linear;
#     white-space: nowrap;
#     border-top: 1px solid #eee;
#     border-left: 1px solid #eee;
#     padding: 0.4em 0.8em;
#     background: #fff;
# }
#
# table tfoot,
# table tbody {
#     outline-offset: -1px;
#     outline: 1px solid #ccc;
# }
#
# table thead {}
#
# table thead th,
# .dataframe thead th {
#     border: none;
#     /*border-bottom: 2px solid #eee;*/
#     background: transparent;
#     color: #fff;
#     text-align: center;
#     cursor: pointer;
#     padding: 0.1em 0.8em;
# }
#
# table tbody {}
#
# table tbody tr:hover td {
#     background: #ffe;
#     color: black;
# }
#
# table tbody tr td:hover {
#     background: #f5f6d2;
# }
#
# table tbody tr td:last-child {
#     text-align: center
# }
#
# table tbody tr th {
#     color: white;
#     padding: 0.4em 0.8em;
#     /*text-transform: uppercase*/
# }
#
# table tfoot {}
# table tfoot td {
#     padding: 0.4em 0.8em;
#     text-align: center;
#     font-style: italic;
# }
#
# table .right {
#     text-align: right
# }
#
# table tbody tr th:first-child {
#     background-color: #777;
#     padding: 0 10px
# }
#
# h1, h2, h3, h4, h5, h6 {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
# }
#
# div.text_cell_render {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 18px;
#     line-height: 26px;
# }
#
# h2 {
#     border-bottom: 1px solid #ccc;
#     padding-bottom: 5px;
# }
#
# p.title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     text-transform: uppercase;
# }
#
# p.experiment-title {
#     color: green;
#     padding: 25px 15px 15px 15px;
# }
#
# p.source-title {
#     color: blue;
#     padding: 15px;
# }
#
# p.anomaly-title {
#     padding: 50px;
#     line-height: 28px;
# }
#
# p.anomaly-title.detected {
#     color: green;
# }
#
# p.anomaly-title.undetected {
#     color: red;
# }
#
# .rendered_html pre,
# .rendered_html code {
#     background-color: #8a6d3b1a;
#     border: 1px solid #ccc;
#     border-right: 1px solid #fff;
#     border-bottom: 1px solid #fff;
#     padding: 1px 5px
#
# }
#
# .text_cell.rendered .rendered_html th,
# .text_cell.rendered .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html th,
# .rendered_html td {
#     font-family: NexusSerif, Georgia,Times New Roman, Times, STIXGeneral, Cambria Math, Lucida Sans Unicode, Microsoft Sans Serif, Segoe UI Symbol, Arial Unicode MS, serif!important;
#     font-size: 16px;
#     line-height: 22px;
# }
#
# .rendered_html td {
#     border-bottom: 1px solid #aaa;
# }
#
# ul, ol {
#     background-color: #f5f5f5;
#     padding: 16px 32px;
# }
#
# .output {
#     font-size: 18px;
# }
#
# .output img {
#     margin: 0 auto;
#     display: flex;
#     border: 1px solid #ddd;
#     padding: 5px;
# }
#
# .output_png img {
#     border: 0;
# }
#
# center {
#     margin: -15px 0 0 0;
#     padding: 0
# }
#
# div.output_prompt {
#     color: white
# }
# </style>
